# %%
import numpy as np 
import pandas as pd
import pyodbc

#CREATE A CONNECTION TO MY DATABASE


#DATABASE DETAILS
server = 'localhost'
database = 'project'
username = 'root'
password = '969297'

# %%
#TABLES_NAME
table_names = ['company_dim2','job_postings_fact2','skills_dim2','skills_job_dim2']
#CONNECTION STRING
conn_str = (
    f'DRIVER={{MySQL ODBC 9.5 Unicode Driver}};'
    f'SERVER={server};DATABASE={database};'
    f'USER={username};PASSWORD={password};'
    'OPTION=3;'
)

# %%
#CONNECT TO MS-SQL SERVER
conn= pyodbc.connect(conn_str)
print("Connection Successfull")
#DICTIONARY TO STORE ALL THE TABLES
dataframes= {}

for table_name in table_names:
    query= f"Select * from {table_name}"
    df= pd.read_sql(query, conn)
    dataframes[table_name]= df

conn.close()
# Out:
# Connection Successfull
# C:\Users\HP\AppData\Local\Temp\ipykernel_63716\3923320527.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(query, conn)

# %%
company= dataframes['company_dim2']
Job_posting= dataframes['job_postings_fact2']
skill_id = dataframes['skills_job_dim2']
skills = dataframes['skills_dim2']

# %%
merge = pd.merge(company, Job_posting, on="company_id", how= "left")

# %%
merge.head()
# Out:
#    company_id        name  link  \
# 0           0  Cryptology  None
# 1           0  Cryptology  None
# 2           0  Cryptology  None
# 3           0  Cryptology  None
# 4           1      Edraak  None
#
#                                          link_google  \
# 0  https://www.google.com/search?sca_esv=56842508...
# 1  https://www.google.com/search?sca_esv=56842508...
# 2  https://www.google.com/search?sca_esv=56842508...
# 3  https://www.google.com/search?sca_esv=56842508...
# 4  https://www.google.com/search?hl=en&gl=us&q=Ed...
#
#                                            thumbnail   job_id job_title_short  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...        0    Data Analyst
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...   923232    Data Analyst
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...  1819517    Data Analyst
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...  1695656    Data Analyst
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...       55  Cloud Engineer
#
#                              job_title         job_location          job_via  \
# 0               Marketing Data Analyst             Anywhere     via LinkedIn
# 1               Marketing Data Analyst             Anywhere     via LinkedIn
# 2               Marketing Data Analyst        Madrid, Spain        via BeBee
# 3               Marketing Data Analyst             Anywhere     via LinkedIn
# 4  Storage and Virtualization Engineer  Kuwait City, Kuwait  via Trabajo.org
#
#   job_schedule_type  job_work_from_home search_location      job_posted_date  \
# 0         Full-time                   1          Serbia  2023-09-25 17:46:06
# 1         Full-time                   1           Spain  2023-09-25 17:51:21
# 2         Full-time                   0           Spain  2023-10-10 10:32:19
# 3         Full-time                   1  United Kingdom  2023-09-25 18:11:19
# 4         Full-time                   0          Kuwait  2023-07-30 17:49:18
#
#    job_no_degree_mention  job_health_insurance     job_country salary_rate  \
# 0                      0                     0          Serbia        None
# 1                      0                     0           Spain        None
# 2                      0                     0           Spain        None
# 3                      0                     0  United Kingdom        None
# 4                      1                     0          Kuwait        None
#
#    salary_year_avg  salary_hour_avg
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN

# %%
skill_id['job_id']=skill_id['job_id'].astype(int)
merge = pd.merge(merge, skill_id, on="job_id", how= "left")

# %%
merge.head()
# Out:
#    company_id        name  link  \
# 0           0  Cryptology  None
# 1           0  Cryptology  None
# 2           0  Cryptology  None
# 3           0  Cryptology  None
# 4           0  Cryptology  None
#
#                                          link_google  \
# 0  https://www.google.com/search?sca_esv=56842508...
# 1  https://www.google.com/search?sca_esv=56842508...
# 2  https://www.google.com/search?sca_esv=56842508...
# 3  https://www.google.com/search?sca_esv=56842508...
# 4  https://www.google.com/search?sca_esv=56842508...
#
#                                            thumbnail  job_id job_title_short  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
#
#                 job_title job_location       job_via  ... job_work_from_home  \
# 0  Marketing Data Analyst     Anywhere  via LinkedIn  ...                  1
# 1  Marketing Data Analyst     Anywhere  via LinkedIn  ...                  1
# 2  Marketing Data Analyst     Anywhere  via LinkedIn  ...                  1
# 3  Marketing Data Analyst     Anywhere  via LinkedIn  ...                  1
# 4  Marketing Data Analyst     Anywhere  via LinkedIn  ...                  1
#
#    search_location      job_posted_date job_no_degree_mention  \
# 0           Serbia  2023-09-25 17:46:06                     0
# 1           Serbia  2023-09-25 17:46:06                     0
# 2           Serbia  2023-09-25 17:46:06                     0
# 3           Serbia  2023-09-25 17:46:06                     0
# 4           Serbia  2023-09-25 17:46:06                     0
#
#    job_health_insurance  job_country salary_rate salary_year_avg  \
# 0                     0       Serbia        None             NaN
# 1                     0       Serbia        None             NaN
# 2                     0       Serbia        None             NaN
# 3                     0       Serbia        None             NaN
# 4                     0       Serbia        None             NaN
#
#    salary_hour_avg  skill_id
# 0              NaN         0
# 1              NaN         1
# 2              NaN       181
# 3              NaN       182
# 4              NaN       183
#
# [5 rows x 21 columns]

# %%
merge = pd.merge(merge, skills, on="skill_id", how= "left")

# %%
merge.head()
# Out:
#    company_id        name  link  \
# 0           0  Cryptology  None
# 1           0  Cryptology  None
# 2           0  Cryptology  None
# 3           0  Cryptology  None
# 4           0  Cryptology  None
#
#                                          link_google  \
# 0  https://www.google.com/search?sca_esv=56842508...
# 1  https://www.google.com/search?sca_esv=56842508...
# 2  https://www.google.com/search?sca_esv=56842508...
# 3  https://www.google.com/search?sca_esv=56842508...
# 4  https://www.google.com/search?sca_esv=56842508...
#
#                                            thumbnail  job_id job_title_short  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...       0    Data Analyst
#
#                 job_title job_location       job_via  ...  \
# 0  Marketing Data Analyst     Anywhere  via LinkedIn  ...
# 1  Marketing Data Analyst     Anywhere  via LinkedIn  ...
# 2  Marketing Data Analyst     Anywhere  via LinkedIn  ...
# 3  Marketing Data Analyst     Anywhere  via LinkedIn  ...
# 4  Marketing Data Analyst     Anywhere  via LinkedIn  ...
#
#        job_posted_date  job_no_degree_mention job_health_insurance  \
# 0  2023-09-25 17:46:06                      0                    0
# 1  2023-09-25 17:46:06                      0                    0
# 2  2023-09-25 17:46:06                      0                    0
# 3  2023-09-25 17:46:06                      0                    0
# 4  2023-09-25 17:46:06                      0                    0
#
#   job_country  salary_rate  salary_year_avg salary_hour_avg skill_id  \
# 0      Serbia         None              NaN             NaN        0
# 1      Serbia         None              NaN             NaN        1
# 2      Serbia         None              NaN             NaN      181
# 3      Serbia         None              NaN             NaN      182
# 4      Serbia         None              NaN             NaN      183
#
#      skills           type
# 0       sql    programming
# 1    python    programming
# 2     excel  analyst_tools
# 3   tableau  analyst_tools
# 4  power bi  analyst_tools
#
# [5 rows x 23 columns]

# %%
columns_to_be_dropped = ['link', 'link_google', 'thumbnail','job_via','job_no_degree_mention', 'job_health_insurance',
       'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
       'skill_id','type']
merge.drop(columns=columns_to_be_dropped,inplace=True)

# %%
merge['skills']= merge['skills'].fillna('').astype(str)

# %%
final_dataframe = merge.groupby(['company_id', 'name', 'job_id', 'job_title_short', 'job_title',
       'job_location', 'job_schedule_type', 'job_work_from_home',
       'search_location', 'job_posted_date'])['skills'].agg(','.join).reset_index()

# %%
final_dataframe.head()
# Out:
#    company_id        name   job_id job_title_short  \
# 0           0  Cryptology        0    Data Analyst
# 1           0  Cryptology   923232    Data Analyst
# 2           0  Cryptology  1695656    Data Analyst
# 3           0  Cryptology  1819517    Data Analyst
# 4           1      Edraak       55  Cloud Engineer
#
#                              job_title         job_location job_schedule_type  \
# 0               Marketing Data Analyst             Anywhere         Full-time
# 1               Marketing Data Analyst             Anywhere         Full-time
# 2               Marketing Data Analyst             Anywhere         Full-time
# 3               Marketing Data Analyst        Madrid, Spain         Full-time
# 4  Storage and Virtualization Engineer  Kuwait City, Kuwait         Full-time
#
#    job_work_from_home search_location      job_posted_date  \
# 0                   1          Serbia  2023-09-25 17:46:06
# 1                   1           Spain  2023-09-25 17:51:21
# 2                   1  United Kingdom  2023-09-25 18:11:19
# 3                   0           Spain  2023-10-10 10:32:19
# 4                   0          Kuwait  2023-07-30 17:49:18
#
#                               skills
# 0  sql,python,excel,tableau,power bi
# 1  sql,python,excel,tableau,power bi
# 2  sql,python,excel,tableau,power bi
# 3  sql,python,excel,tableau,power bi
# 4                             vmware
